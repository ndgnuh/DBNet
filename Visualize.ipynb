# %%
from dbnet.datasets import DBNetDataset
from dbnet.transform_albumen import get_augment

# %%
data = DBNetDataset("examples/lmdb/train/", get_augment(enabled=True, rotate=True, prob=0.3))

# %%
data.visualize(10)
# Out:
# sample 0
# sample 1
