# %%
# !python mk_train_data.py config.yml
# Out:
# Encoding samples: 100%|███████████████████████████| 4/4 [00:01<00:00,  2.03it/s]
# Creating dataset: 100%|███████████████████████████| 4/4 [00:03<00:00,  1.29it/s]Output is written in lmdb/train_data
# Creating dataset: 100%|███████████████████████████| 4/4 [00:03<00:00,  1.28it/s]
# Encoding samples: 100%|███████████████████████████| 4/4 [00:01<00:00,  2.03it/s]
# Creating dataset: 100%|███████████████████████████| 4/4 [00:03<00:00,  1.29it/s]Output is written in lmdb/val_lmdb
# Creating dataset: 100%|███████████████████████████| 4/4 [00:03<00:00,  1.29it/s]

# %%
# !pip install -q matplotlib
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from dbnet.datasets import DBNetDataset
from dbnet.transform_albumen import get_augment

# %%
data = DBNetDataset("./lmdb/train_data/", get_augment())

# %%
data.visualize()
# Out:
# sample 0
# sample 1
# sample 2
# sample 3
